# %% [markdown]
# <a href="https://colab.research.google.com/github/alexandrexsant/analise_de_populacao_dos_estados_brasileiros_com_dados_do_IBGE/blob/main/analise_de_populacao_dos_estados_brasileiros_com_dados_do_IBGE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
# Ordenar os estados por população e selecionar os 10 mais populosos
df_sorted = df.sort_values(by="Populacao", ascending=False).head(10)

# %%
# Criar gráfico de barras mostrando os 10 estados mais populosos
plt.figure(figsize=(12, 6))
sns.barplot(data=df_sorted, x="Estado", y=df_sorted["Populacao"].astype(int), hue="Estado", palette="viridis", legend=False)
plt.xticks(rotation=45)
plt.title("Top 10 Estados Mais Populosos (IBGE 2021)")
plt.xlabel("Estado")
plt.ylabel("População")
plt.show()

# %%
# Análise da distribuição da população
# O histograma abaixo mostra como a população dos estados está distribuída.
# Ele ajuda a entender a concentração da população e se existem outliers.
plt.figure(figsize=(12, 6))
sns.histplot(df["Populacao"].astype(int), bins=20, kde=True, color="blue")
plt.title("Distribuição da População dos Estados (IBGE 2021)")
plt.xlabel("População")
plt.ylabel("Frequência")
plt.show()

# %%
# Análise de dispersão entre os estados e suas populações
# O gráfico de dispersão abaixo exibe a população de cada estado individualmente.
# Ele permite visualizar a variação populacional entre os estados.
plt.figure(figsize=(12, 6))
sns.scatterplot(data=df, x="Estado", y=df["Populacao"].astype(int), color="red")
plt.xticks(rotation=90)
plt.title("Dispersão da População por Estado (IBGE 2021)")
plt.xlabel("Estado")
plt.ylabel("População")
plt.show()

# %%
# Exibir estatísticas descritivas dos dados de população
# Aqui, são calculadas estatísticas básicas, como média, mediana, mínimo e máximo da população por estado.
print("Estatísticas Descritivas da População por Estado:")
print(df["Populacao"].astype(int).describe())
# Out:
# Estatísticas Descritivas da População por Estado:
# count    2.700000e+01
# mean     7.900653e+06
# std      9.380644e+06
# min      6.527130e+05
# 25%      2.966756e+06
# 50%      4.108508e+06
# 75%      9.457686e+06
# max      4.664913e+07
# Name: Populacao, dtype: float64
